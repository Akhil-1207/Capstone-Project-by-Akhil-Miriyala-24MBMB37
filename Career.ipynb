# %% [markdown]
# ###Bronze Layer

# %%
df=spark.table("Career_Guidance")

# %%
from pyspark.sql.functions import col, count

# %% [markdown]
# ###Silver Layer

# %%
# 3.1: Check for duplicates and remove if any
original_count = df.count()
df = df.dropDuplicates()
dedup_count = df.count()
print(f"Original rows: {original_count}, After dedup: {dedup_count}")
# Out:
# Original rows: 1000, After dedup: 1000

# %%
# 3.2: Handle data types (ensure Salary_LPA is double, ID is int)
df = df.withColumn("Salary_LPA", col("Salary_LPA").cast("double"))
df = df.withColumn("ID", col("ID").cast("int"))

# %%
from pyspark.sql.functions import col, trim

string_cols = [
    "Sector",
    "Stream",
    "Course",
    "Qualification",
    "Career",
    "Demand_2025"
]

for col_name in string_cols:
    df = df.withColumn(
        col_name,
        trim(col(col_name).cast("string"))
    )

display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Sector</th><th>Stream</th><th>Course</th><th>Qualification</th><th>Career</th><th>Salary_LPA</th><th>Demand_2025</th></tr></thead><tbody><tr><td>1</td><td>AI & ML</td><td>Commerce</td><td>B.Com</td><td>10+2 + Bachelor's</td><td>Prompt Engineer (AI & ML)</td><td>9.6</td><td>High</td></tr><tr><td>2</td><td>Engineering</td><td>Commerce</td><td>BHM</td><td>10+2 + Diploma</td><td>Electrical Engineer (Engineering)</td><td>11.1</td><td>Stable</td></tr><tr><td>3</td><td>Green Energy</td><td>Science (PCB)</td><td>B.Sc Nursing</td><td>10+2 + NEET</td><td>Renewable Energy Engineer (Green Energy)</td><td>12.6</td><td>Evergreen</td></tr><tr><td>4</td><td>Science & Research</td><td>Any Stream</td><td>LLB</td><td>Bachelor's + UPSC</td><td>Biotechnologist (Science & Research)</td><td>4.0</td><td>Emerging</td></tr><tr><td>5</td><td>Hospitality & Travel</td><td>Science (PCM)</td><td>B.Tech Civil</td><td>10+2 + JEE</td><td>Hotel Manager (Hospitality & Travel)</td><td>11.2</td><td>High</td></tr></tbody></table></div>

# %%
# Display preprocessed data
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Sector</th><th>Stream</th><th>Course</th><th>Qualification</th><th>Career</th><th>Salary_LPA</th><th>Demand_2025</th></tr></thead><tbody><tr><td>1</td><td>AI & ML</td><td>Commerce</td><td>B.Com</td><td>10+2 + Bachelor's</td><td>Prompt Engineer (AI & ML)</td><td>9.6</td><td>High</td></tr><tr><td>2</td><td>Engineering</td><td>Commerce</td><td>BHM</td><td>10+2 + Diploma</td><td>Electrical Engineer (Engineering)</td><td>11.1</td><td>Stable</td></tr><tr><td>3</td><td>Green Energy</td><td>Science (PCB)</td><td>B.Sc Nursing</td><td>10+2 + NEET</td><td>Renewable Energy Engineer (Green Energy)</td><td>12.6</td><td>Evergreen</td></tr><tr><td>4</td><td>Science & Research</td><td>Any Stream</td><td>LLB</td><td>Bachelor's + UPSC</td><td>Biotechnologist (Science & Research)</td><td>4.0</td><td>Emerging</td></tr><tr><td>5</td><td>Hospitality & Travel</td><td>Science (PCM)</td><td>B.Tech Civil</td><td>10+2 + JEE</td><td>Hotel Manager (Hospitality & Travel)</td><td>11.2</td><td>High</td></tr></tbody></table></div>

# %% [markdown]
# ###Gold Layer

# %%
# 4.2: Demand distribution
demand_dist = df.groupBy("Demand_2025").agg(count("*").alias("Count")).orderBy(desc("Count"))
display(demand_dist)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Demand_2025</th><th>Count</th></tr></thead><tbody><tr><td>Emerging</td><td>205</td></tr><tr><td>Evergreen</td><td>204</td></tr><tr><td>Growing</td><td>201</td></tr><tr><td>High</td><td>196</td></tr><tr><td>Stable</td><td>194</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# 4.3: Top careers by salary
top_careers = df.orderBy(desc("Salary_LPA")).limit(10)
display(top_careers)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Sector</th><th>Stream</th><th>Course</th><th>Qualification</th><th>Career</th><th>Salary_LPA</th><th>Demand_2025</th></tr></thead><tbody><tr><td>23</td><td>FinTech</td><td>Science (PCM/CS)</td><td>B.Tech Aerospace</td><td>10+2 + JEE</td><td>Blockchain Specialist (FinTech)</td><td>25.0</td><td>Stable</td></tr><tr><td>608</td><td>Cybersecurity</td><td>Science (PCM/CS)</td><td>B.Sc Data Science</td><td>Bachelor's + Cert</td><td>Security Analyst (Cybersecurity) Variant 520</td><td>24.9</td><td>High</td></tr><tr><td>896</td><td>Government & Defense</td><td>Science (PCM/CS)</td><td>B.Sc Data Science</td><td>10+2 + Diploma</td><td>Metaverse Designer (Government)</td><td>24.9</td><td>Emerging</td></tr><tr><td>95</td><td>Law</td><td>Science (PCB)</td><td>BDS</td><td>10+2 + NEET</td><td>Judge (Law)</td><td>24.9</td><td>Stable</td></tr><tr><td>180</td><td>Education</td><td>Science (PCM)</td><td>B.Tech CSE</td><td>10+2 + JEE</td><td>Professor (Education) Variant 106</td><td>24.9</td><td>Emerging</td></tr><tr><td>80</td><td>Engineering</td><td>Science (PCM/CS)</td><td>B.Sc Data Science</td><td>10+2 + Diploma</td><td>Aerospace Engineer (Engineering)</td><td>24.9</td><td>High</td></tr><tr><td>346</td><td>Engineering</td><td>Science (PCM/CS)</td><td>B.Tech CSE</td><td>10+2 + JEE</td><td>Aerospace Engineer (Engineering) Variant 264</td><td>24.8</td><td>Emerging</td></tr><tr><td>207</td><td>Media & Design</td><td>Science (PCM/CS)</td><td>B.Tech Aerospace</td><td>10+2 + JEE</td><td>Journalist (Media & Design) Variant 129</td><td>24.8</td><td>Evergreen</td></tr><tr><td>546</td><td>Government & Defense</td><td>Any Stream</td><td>LLB</td><td>Bachelor's + UPSC</td><td>Policy Maker (Government & Defense) Variant 460</td><td>24.8</td><td>Stable</td></tr><tr><td>163</td><td>Gig Economy</td><td>Science (PCM/CS)</td><td>B.Tech Aerospace</td><td>10+2 + JEE</td><td>Platform Developer (Gig Economy) Variant 90</td><td>24.7</td><td>Growing</td></tr></tbody></table></div>

# %%
# 4.4: Register as temp table for SQL analytics
df.createOrReplaceTempView("careers")
sql_query = """
SELECT Stream, COUNT(*) as Count, AVG(Salary_LPA) as Avg_Salary
FROM careers
GROUP BY Stream
ORDER BY Avg_Salary DESC
"""
sql_result = spark.sql(sql_query)
display(sql_result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Stream</th><th>Count</th><th>Avg_Salary</th></tr></thead><tbody><tr><td>Science (PCM/CS)</td><td>119</td><td>14.615126050420166</td></tr><tr><td>Any Stream</td><td>191</td><td>14.290575916230368</td></tr><tr><td>Science (PCM)</td><td>257</td><td>13.859922178988338</td></tr><tr><td>Arts</td><td>81</td><td>13.670370370370378</td></tr><tr><td>Commerce</td><td>117</td><td>13.607692307692307</td></tr><tr><td>Science (PCB)</td><td>235</td><td>13.58042553191489</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ###Big Data Analytics

# %%
from pyspark.ml.feature import StringIndexer

indexers = [
    StringIndexer(
        inputCol=col,
        outputCol=col + "_index"
    )
    for col in [
        "Sector",
        "Stream",
        "Course",
        "Qualification",
        "Demand_2025"
    ]
]

# %%
from pyspark.ml.feature import OneHotEncoder

encoders = [
    OneHotEncoder(
        inputCol=col + "_index",
        outputCol=col + "_ohe"
    )
    for col in [
        "Sector",
        "Stream",
        "Course",
        "Qualification",
        "Demand_2025"
    ]
]

# %%
# 5.3: Assemble features into a vector (for potential ML)
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=["Salary_LPA"] + [
        col + "_ohe"
        for col in [
            "Sector",
            "Stream",
            "Course",
            "Qualification",
            "Demand_2025"
        ]
    ],
    outputCol="features"
)

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=["Salary_LPA"] + [
        col + "_ohe"
        for col in [
            "Sector",
            "Stream",
            "Course",
            "Qualification",
            "Demand_2025"
        ]
    ],
    outputCol="features"
)

# %%
# Display extracted features
from pyspark.ml import Pipeline

pipeline = Pipeline(
    stages=indexers + encoders + [assembler]
)
model = pipeline.fit(df)
df_features = model.transform(df)

# %% [markdown]
# ### **Platinum Layer**

# %% [markdown]
# > ###A student can select any column by filter as his preference and get results

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Sector</th><th>Stream</th><th>Course</th><th>Qualification</th><th>Career</th><th>Salary_LPA</th><th>Demand_2025</th></tr></thead><tbody><tr><td>1</td><td>AI & ML</td><td>Commerce</td><td>B.Com</td><td>10+2 + Bachelor's</td><td>Prompt Engineer (AI & ML)</td><td>9.6</td><td>High</td></tr><tr><td>2</td><td>Engineering</td><td>Commerce</td><td>BHM</td><td>10+2 + Diploma</td><td>Electrical Engineer (Engineering)</td><td>11.1</td><td>Stable</td></tr><tr><td>3</td><td>Green Energy</td><td>Science (PCB)</td><td>B.Sc Nursing</td><td>10+2 + NEET</td><td>Renewable Energy Engineer (Green Energy)</td><td>12.6</td><td>Evergreen</td></tr><tr><td>4</td><td>Science & Research</td><td>Any Stream</td><td>LLB</td><td>Bachelor's + UPSC</td><td>Biotechnologist (Science & Research)</td><td>4.0</td><td>Emerging</td></tr><tr><td>5</td><td>Hospitality & Travel</td><td>Science (PCM)</td><td>B.Tech Civil</td><td>10+2 + JEE</td><td>Hotel Manager (Hospitality & Travel)</td><td>11.2</td><td>High</td></tr><tr><td>6</td><td>Gig Economy</td><td>Any Stream</td><td>LLB</td><td>10+2 + Diploma</td><td>Gig Worker Coordinator (Gig Economy)</td><td>11.7</td><td>Stable</td></tr><tr><td>7</td><td>Hospitality & Travel</td><td>Science (P